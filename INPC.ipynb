# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_excel('/content/INPC - Variação mensal, acumulada no ano e peso mensal, segundo o índice geral e os grupos de produt.xlsx')
dados.head()
# Out:
#   INPC - Variação mensal, acumulada no ano e peso mensal, segundo o índice geral e os grupos de produtos e serviços  \
# 0                                Brasil - julho 2022
# 1       Índice geral e grupos de produtos e serviços
# 2                                       Índice geral
# 3                              Alimentação e bebidas
# 4                                          Habitação
#
#             Unnamed: 1                     Unnamed: 2       Unnamed: 3
# 0                  NaN                            NaN              NaN
# 1  Variação mensal (%)  Variação acumulada no ano (%)  Peso mensal (%)
# 2                 -0.6                           4.98              100
# 3                 1.31                          10.09          24.2459
# 4                -0.83                          -1.29          17.1103

# %%
dados.shape
# Out:
# (13, 4)

# %%
dados
# Out:
#    INPC - Variação mensal, acumulada no ano e peso mensal, segundo o índice geral e os grupos de produtos e serviços  \
# 0                                 Brasil - julho 2022
# 1        Índice geral e grupos de produtos e serviços
# 2                                        Índice geral
# 3                               Alimentação e bebidas
# 4                                           Habitação
# 5                               Artigos de residência
# 6                                           Vestuário
# 7                                         Transportes
# 8                           Saúde e cuidados pessoais
# 9                                   Despesas pessoais
# 10                                           Educação
# 11                                        Comunicação
# 12  Fonte: IBGE - Índice Nacional de Preços ao Con...
#
#              Unnamed: 1                     Unnamed: 2       Unnamed: 3
# 0                   NaN                            NaN              NaN
# ...

# %%
dados.rename(columns={
    'INPC - Variação mensal, acumulada no ano e peso mensal, segundo o índice geral e os grupos de produtos e serviços': 'Índice geral e grupos de produtos e serviços',
    'Unnamed: 1': 'Variação mensal (%)',
    'Unnamed: 2': 'Variação acumulada no ano (%)',
    'Unnamed: 3': 'Peso mensal (%)'
}, inplace=True)

# %%
dados.drop(index=[0, 1], inplace=True)

# %%
dados
# Out:
#          Índice geral e grupos de produtos e serviços Variação mensal (%)  \
# 2                                        Índice geral                -0.6
# 3                               Alimentação e bebidas                1.31
# 4                                           Habitação               -0.83
# 5                               Artigos de residência                 0.2
# 6                                           Vestuário                0.65
# 7                                         Transportes               -4.44
# 8                           Saúde e cuidados pessoais                0.27
# 9                                   Despesas pessoais                1.05
# 10                                           Educação                 0.1
# 11                                        Comunicação                0.07
# 12  Fonte: IBGE - Índice Nacional de Preços ao Con...                 NaN
#
#    Variação acumulada no ano (%) Peso mensal (%)
# ...

# %%
dados.drop(12, inplace=True)

# %%
dados
# Out:
#    Índice geral e grupos de produtos e serviços Variação mensal (%)  \
# 2                                  Índice geral                -0.6
# 3                         Alimentação e bebidas                1.31
# 4                                     Habitação               -0.83
# 5                         Artigos de residência                 0.2
# 6                                     Vestuário                0.65
# 7                                   Transportes               -4.44
# 8                     Saúde e cuidados pessoais                0.27
# 9                             Despesas pessoais                1.05
# 10                                     Educação                 0.1
# 11                                  Comunicação                0.07
#
#    Variação acumulada no ano (%) Peso mensal (%)
# 2                           4.98             100
# 3                          10.09         24.2459
# 4                          -1.29         17.1103
# ...
