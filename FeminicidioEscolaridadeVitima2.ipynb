# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
Dados = pd.read_csv('/content/Balanco-2019-Ligue180-Escolaridade Vitima.csv', encoding='latin-1')
Dados.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN         NaN
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# ...

# %%
Dados.shape
# Out:
# (26, 15)

# %%
Dados.isnull().sum()
# Out:
# Unnamed: 0     26
# Unnamed: 1      8
# Unnamed: 2     10
# Unnamed: 3     11
# Unnamed: 4     11
# Unnamed: 5     11
# Unnamed: 6     11
# Unnamed: 7     11
# Unnamed: 8     11
# Unnamed: 9     11
# Unnamed: 10    11
# Unnamed: 11    11
# Unnamed: 12    11
# Unnamed: 13    11
# Unnamed: 14    11
# dtype: int64

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   18 non-null     object
#  2   Unnamed: 2   16 non-null     object
#  3   Unnamed: 3   15 non-null     object
#  4   Unnamed: 4   15 non-null     object
#  5   Unnamed: 5   15 non-null     object
#  6   Unnamed: 6   15 non-null     object
#  7   Unnamed: 7   15 non-null     object
#  8   Unnamed: 8   15 non-null     object
#  9   Unnamed: 9   15 non-null     object
#  10  Unnamed: 10  15 non-null     object
#  11  Unnamed: 11  15 non-null     object
#  12  Unnamed: 12  15 non-null     object
#  13  Unnamed: 13  15 non-null     object
#  14  Unnamed: 14  15 non-null     object
# dtypes: float64(1), object(14)
# memory usage: 3.2+ KB

# %%
Dados.drop(index=[0, 1, 2, 3, 4, 5, 6, 7], inplace=True)

# %%
Dados
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 8          NaN                            Escolaridade da VÃ­tima        Jan
# 9          NaN                                      Analfabeto(a)        237
# 10         NaN                      Ensino Fundamental Incompleto      1,999
# 11         NaN                        Ensino Fundamental completo        611
# 12         NaN                           Ensino MÃ©dio Incompleto        823
# 13         NaN                             Ensino MÃ©dio completo      2,421
# 14         NaN                                    NÃ­vel TÃ©cnico          0
# 15         NaN                         Ensino Superior Incompleto        523
# 16         NaN                           Ensino Superior completo        786
# 17         NaN                                   PÃ³s GraduaÃ§Ã£o          0
# 18         NaN                                   EspecializaÃ§Ã£o         85
# ...

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 8 to 25
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   17 non-null     object
#  2   Unnamed: 2   15 non-null     object
#  3   Unnamed: 3   15 non-null     object
#  4   Unnamed: 4   15 non-null     object
#  5   Unnamed: 5   15 non-null     object
#  6   Unnamed: 6   15 non-null     object
#  7   Unnamed: 7   15 non-null     object
#  8   Unnamed: 8   15 non-null     object
#  9   Unnamed: 9   15 non-null     object
#  10  Unnamed: 10  15 non-null     object
#  11  Unnamed: 11  15 non-null     object
#  12  Unnamed: 12  15 non-null     object
#  13  Unnamed: 13  15 non-null     object
#  14  Unnamed: 14  15 non-null     object
# dtypes: float64(1), object(14)
# memory usage: 2.2+ KB

# %%
Dados.drop(index=[23, 24, 25], inplace=True)

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 8 to 22
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   15 non-null     object
#  2   Unnamed: 2   15 non-null     object
#  3   Unnamed: 3   15 non-null     object
#  4   Unnamed: 4   15 non-null     object
#  5   Unnamed: 5   15 non-null     object
#  6   Unnamed: 6   15 non-null     object
#  7   Unnamed: 7   15 non-null     object
#  8   Unnamed: 8   15 non-null     object
#  9   Unnamed: 9   15 non-null     object
#  10  Unnamed: 10  15 non-null     object
#  11  Unnamed: 11  15 non-null     object
#  12  Unnamed: 12  15 non-null     object
#  13  Unnamed: 13  15 non-null     object
#  14  Unnamed: 14  15 non-null     object
# dtypes: float64(1), object(14)
# memory usage: 1.9+ KB

# %%
Dados.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='object')

# %%
Dados.rename(columns = {
    'Unnamed: 1': 'Escolaridade da Vítima', 
    'Unnamed: 2': 'Jan',
    'Unnamed: 3': 'Fev',
    'Unnamed: 4': 'Mar',
    'Unnamed: 5': 'Abr',
    'Unnamed: 6': 'Mai',
    'Unnamed: 7': 'Jun',
    'Unnamed: 8': 'Jul', 
    'Unnamed: 9': 'Ago',
    'Unnamed: 10': 'Set',
    'Unnamed: 11': 'Out',
    'Unnamed: 12': 'Nov',
    'Unnamed: 13': 'Dez',
    'Unnamed: 14': 'Total 2019'
}, inplace=True)

# %%
Dados
# Out:
#     Unnamed: 0         Escolaridade da Vítima    Jan    Fev    Mar    Abr  \
# 8          NaN        Escolaridade da VÃ­tima    Jan    Fev    Mar    Abr
# 9          NaN                  Analfabeto(a)    237    202    201    168
# 10         NaN  Ensino Fundamental Incompleto  1,999  1,691  1,830  1,653
# 11         NaN    Ensino Fundamental completo    611    465    497    415
# 12         NaN       Ensino MÃ©dio Incompleto    823    640    761    687
# 13         NaN         Ensino MÃ©dio completo  2,421  1,903  2,062  1,862
# 14         NaN                NÃ­vel TÃ©cnico      0      0      0      0
# 15         NaN     Ensino Superior Incompleto    523    447    477    460
# 16         NaN       Ensino Superior completo    786    685    758    600
# 17         NaN               PÃ³s GraduaÃ§Ã£o      0      0      0      0
# 18         NaN               EspecializaÃ§Ã£o     85     79     90     72
# 19         NaN                       Mestrado     11     10     14     12
# ...

# %%
Dados.drop(index=[8], inplace=True)

# %%
Dados = Dados.reset_index()

# %%
Dados.drop(columns=['index'], inplace=True)

# %%
Dados.head()
# Out:
#    Unnamed: 0         Escolaridade da Vítima    Jan    Fev    Mar    Abr  \
# 0         NaN                  Analfabeto(a)    237    202    201    168
# 1         NaN  Ensino Fundamental Incompleto  1,999  1,691  1,830  1,653
# 2         NaN    Ensino Fundamental completo    611    465    497    415
# 3         NaN       Ensino MÃ©dio Incompleto    823    640    761    687
# 4         NaN         Ensino MÃ©dio completo  2,421  1,903  2,062  1,862
#
#      Mai    Jun    Jul    Ago    Set    Out    Nov  Dez Total 2019
# 0    143    141    121    169    161    145    151   82      1,921
# 1  1,629  1,431  1,513  1,756  1,634  1,600  1,416  758     18,910
# 2    428    396    417    447    440    412    377  197      5,102
# 3    684    523    615    723    608    696    610  286      7,656
# 4  1,843  1,653  1,752  2,063  1,928  1,874  1,784  908     22,053

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              0 non-null      float64
#  1   Escolaridade da Vítima  14 non-null     object
#  2   Jan                     14 non-null     object
#  3   Fev                     14 non-null     object
#  4   Mar                     14 non-null     object
#  5   Abr                     14 non-null     object
#  6   Mai                     14 non-null     object
#  7   Jun                     14 non-null     object
#  8   Jul                     14 non-null     object
#  9   Ago                     14 non-null     object
#  10  Set                     14 non-null     object
#  11  Out                     14 non-null     object
#  12  Nov                     14 non-null     object
#  13  Dez                     14 non-null     object
# ...

# %%
#mesmo tendo feito a alteraçao da virgula para o ponto, visando transformar os valores de object para float, ainda possui erros
#no caso, os valores que antes era, por exemplo, casa das centenas, com a inclusao do ponto, passaram a ser das cadas dos milhares
#como se nota na versao "FeminicidioEscolaridadeVitima".
#Coluna Abr, linha "Analfabeto(a)", o valor apresentado é de 168.000 (mil), mas que na verdade, foram 168. 
#Assim, os dados estao errados. Fiz a correção logo abaixo, onde ao inves de virarem float, passaram a ser inteiros.
#para isso ocorrer, foi retirado o ponto/virgula e substituido por nada.

# %%
Dados['Jan'] = pd.to_numeric(Dados['Jan'].apply(lambda linha1: linha1.replace(',', '')))

# %%
Dados['Fev'] = pd.to_numeric(Dados['Fev'].apply(lambda linha2: linha2.replace(',', '')))

# %%
Dados['Mar'] = pd.to_numeric(Dados['Mar'].apply(lambda linha3: linha3.replace(',', '')))

# %%
Dados['Abr'] = pd.to_numeric(Dados['Abr'].apply(lambda linha4: linha4.replace(',', '')))

# %%
Dados['Mai'] = pd.to_numeric(Dados['Mai'].apply(lambda linha5: linha5.replace(',', '')))

# %%
Dados['Jun'] = pd.to_numeric(Dados['Jun'].apply(lambda linha6: linha6.replace(',', '')))

# %%
Dados['Jul'] = pd.to_numeric(Dados['Jul'].apply(lambda linha7: linha7.replace(',', '')))

# %%
Dados['Ago'] = pd.to_numeric(Dados['Ago'].apply(lambda linha8: linha8.replace(',', '')))

# %%
Dados['Set'] = pd.to_numeric(Dados['Set'].apply(lambda linha9: linha9.replace(',', '')))

# %%
Dados['Out'] = pd.to_numeric(Dados['Out'].apply(lambda linha10: linha10.replace(',', '')))

# %%
Dados['Nov'] = pd.to_numeric(Dados['Nov'].apply(lambda linha11: linha11.replace(',', '')))

# %%
Dados['Dez'] = pd.to_numeric(Dados['Dez'].apply(lambda linha12: linha12.replace(',', '')))

# %%
Dados.drop(columns=['Unnamed: 0'], inplace=True)

# %%
Dados.drop(columns=['Total 2019'], inplace=True)

# %%
Dados.drop(index=13, inplace=True)

# %%
#mesmo tendo feito a alteraçao da virgula para o ponto, visando transformar os valores de object para float, ainda possui erros
#no caso, os valores que antes era, por exemplo, casa das centenas, com a inclusao do ponto, passaram a ser das cadas dos milhares
#como se nota na imagem abaixo.
#Coluna Abr, linha "Analfabeto(a)", o valor apresentado é de 168.000 (mil), mas que na verdade, foram 168. 
#Assim, os dados estao errados. Fiz a correção logo ao final, onde ao inves de virarem float, passaram a ser inteiros.
#para isso ocorrer, foi retirado o ponto final e substituido por nada.
Dados.head()
# Out:
#           Escolaridade da Vítima   Jan   Fev   Mar   Abr   Mai   Jun   Jul  \
# 0                  Analfabeto(a)   237   202   201   168   143   141   121
# 1  Ensino Fundamental Incompleto  1999  1691  1830  1653  1629  1431  1513
# 2    Ensino Fundamental completo   611   465   497   415   428   396   417
# 3       Ensino MÃ©dio Incompleto   823   640   761   687   684   523   615
# 4         Ensino MÃ©dio completo  2421  1903  2062  1862  1843  1653  1752
#
#     Ago   Set   Out   Nov  Dez
# 0   169   161   145   151   82
# 1  1756  1634  1600  1416  758
# 2   447   440   412   377  197
# 3   723   608   696   610  286
# 4  2063  1928  1874  1784  908

# %%
Dados = Dados.set_index('Escolaridade da Vítima')

# %%
Dados.head()
# Out:
#                                 Jan   Fev   Mar   Abr   Mai   Jun   Jul   Ago  \
# Escolaridade da Vítima
# Analfabeto(a)                   237   202   201   168   143   141   121   169
# Ensino Fundamental Incompleto  1999  1691  1830  1653  1629  1431  1513  1756
# Ensino Fundamental completo     611   465   497   415   428   396   417   447
# Ensino MÃ©dio Incompleto        823   640   761   687   684   523   615   723
# Ensino MÃ©dio completo         2421  1903  2062  1862  1843  1653  1752  2063
#
#                                 Set   Out   Nov  Dez
# Escolaridade da Vítima
# Analfabeto(a)                   161   145   151   82
# Ensino Fundamental Incompleto  1634  1600  1416  758
# Ensino Fundamental completo     440   412   377  197
# Ensino MÃ©dio Incompleto        608   696   610  286
# Ensino MÃ©dio completo         1928  1874  1784  908

# %%
#A fundção "T", é o equivalente a transpor, ou seja, transforma coluna em linha e, linha e coluna
Dados = Dados.T
Dados
# Out:
# Escolaridade da Vítima  Analfabeto(a)  Ensino Fundamental Incompleto  \
# Jan                               237                           1999
# Fev                               202                           1691
# Mar                               201                           1830
# Abr                               168                           1653
# Mai                               143                           1629
# Jun                               141                           1431
# Jul                               121                           1513
# Ago                               169                           1756
# Set                               161                           1634
# Out                               145                           1600
# Nov                               151                           1416
# Dez                                82                            758
#
# ...

# %%
Dados.head()
# Out:
# Escolaridade da Vítima  Analfabeto(a)  Ensino Fundamental Incompleto  \
# Jan                               237                           1999
# Fev                               202                           1691
# Mar                               201                           1830
# Abr                               168                           1653
# Mai                               143                           1629
#
# Escolaridade da Vítima  Ensino Fundamental completo  Ensino MÃ©dio Incompleto  \
# Jan                                             611                       823
# Fev                                             465                       640
# Mar                                             497                       761
# Abr                                             415                       687
# Mai                                             428                       684
#
# Escolaridade da Vítima  Ensino MÃ©dio completo  NÃ­vel TÃ©cnico  \
# ...

# %%
sns.barplot(Dados.index, y=Dados['Analfabeto(a)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(x=Dados.index, y=Dados['Analfabeto(a)'])

# %%
sns.boxplot(Dados.index, y=Dados['Analfabeto(a)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Analise = Dados.groupby(Dados.index).sum()['Analfabeto(a)'].reset_index()
Analise
# Out:
#    index  Analfabeto(a)
# 0    Abr            168
# 1    Ago            169
# 2    Dez             82
# 3    Fev            202
# 4    Jan            237
# 5    Jul            121
# 6    Jun            141
# 7    Mai            143
# 8    Mar            201
# 9    Nov            151
# 10   Out            145
# 11   Set            161

# %%
sns.barplot(Analise['index'], y=Analise['Analfabeto(a)'], order=['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(Analise['index'], y=Analise['Analfabeto(a)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.bar(Analise['index'], Analise['Analfabeto(a)'])
#plt, não possui o order, para organizar o gráfico de acordo com o mes.
# Out:
# <BarContainer object of 12 artists>

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Jan to Dez
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Analfabeto(a)                  12 non-null     int64
#  1   Ensino Fundamental Incompleto  12 non-null     int64
#  2   Ensino Fundamental completo    12 non-null     int64
#  3   Ensino MÃ©dio Incompleto       12 non-null     int64
#  4   Ensino MÃ©dio completo         12 non-null     int64
#  5   NÃ­vel TÃ©cnico                12 non-null     int64
#  6   Ensino Superior Incompleto     12 non-null     int64
#  7   Ensino Superior completo       12 non-null     int64
#  8   PÃ³s GraduaÃ§Ã£o               12 non-null     int64
#  9   EspecializaÃ§Ã£o               12 non-null     int64
#  10  Mestrado                       12 non-null     int64
#  11  Doutorado                      12 non-null     int64
# ...

# %%
#calculando mortes por grupo de alfabetização
Dados.sum(axis=0)
# Out:
# Escolaridade da Vítima
# Analfabeto(a)                     1921
# Ensino Fundamental Incompleto    18910
# Ensino Fundamental completo       5102
# Ensino MÃ©dio Incompleto          7656
# Ensino MÃ©dio completo           22053
# NÃ­vel TÃ©cnico                      0
# Ensino Superior Incompleto        5344
# Ensino Superior completo          7450
# PÃ³s GraduaÃ§Ã£o                     0
# EspecializaÃ§Ã£o                   830
# Mestrado                           142
# Doutorado                           26
# NÃ£o informado                   15978
# dtype: int64

# %%
#calculando vitimas por mes.
Dados.sum(axis=1)
# Out:
# Jan    9549
# Fev    7669
# Mar    8440
# Abr    7243
# Mai    7309
# Jun    6300
# Jul    6442
# Ago    7628
# Set    7312
# Out    7280
# Nov    6688
# Dez    3552
# dtype: int64
